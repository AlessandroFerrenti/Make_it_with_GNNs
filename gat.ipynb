# %%
import argparse
import numpy as np
import networkx as nx
import time
import torch
import torch.nn.functional as F
import dgl
from dgl.data import register_data_args
from dgl.data import CoraGraphDataset, CiteseerGraphDataset, PubmedGraphDataset

from gat import GAT
from utils import EarlyStopping

# %%
def accuracy(logits, labels):
    _, indices = torch.max(logits, dim=1)
    correct = torch.sum(indices == labels)
    return correct.item() * 1.0 / len(labels)

# %%
def evaluate(model, features, labels, mask):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        return accuracy(logits, labels)

# %%
#param:
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs = 200
num_heads = 8
num_out_heads = 1
num_layers = 3
num_hidden = [16,8,4]
residual = False
in_drop = .06
attn_drop = .06
lr = 0.005
weight_decay = 5e-4
negative_slope = 0.2
early_stop = False
fastmode = False


data = CoraGraphDataset()


g = data[0]


features = g.ndata['feat']
labels = g.ndata['label']
train_mask = g.ndata['train_mask']
val_mask = g.ndata['val_mask']
test_mask = g.ndata['test_mask']
num_feats = features.shape[1]
n_classes = data.num_labels
n_edges = g.number_of_edges()
print("""----Data statistics------'
  #Edges %d
  #Classes %d
  #Train samples %d
  #Val samples %d
  #Test samples %d""" %
      (n_edges, n_classes,
       train_mask.int().sum().item(),
       val_mask.int().sum().item(),
       test_mask.int().sum().item()))

# add self loop
g = dgl.remove_self_loop(g)
g = dgl.add_self_loop(g)
n_edges = g.number_of_edges()
# create model
heads = ([num_heads] * (num_layers-1)) + [num_out_heads]
# print(heads)
model = GAT(g,
            num_layers,
            num_feats,
            num_hidden,
            n_classes,
            heads,
            F.elu,
            in_drop,
            attn_drop,
            negative_slope,
            residual)
print(model)
if early_stop:
    stopper = EarlyStopping(patience=100)

model.to(device)
loss_fcn = torch.nn.CrossEntropyLoss()

# use optimizer
optimizer = torch.optim.Adam(
    model.parameters(), lr=lr, weight_decay=weight_decay)

# initialize graph
dur = []
for epoch in range(epochs):
    model.train()
    
    # forward
    logits = model(features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    train_acc = accuracy(logits[train_mask], labels[train_mask])

    if fastmode:
        val_acc = accuracy(logits[val_mask], labels[val_mask])
    else:
        val_acc = evaluate(model, features, labels, val_mask)
        if early_stop:
            if stopper.step(val_acc, model):
                break

    print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | TrainAcc {:.4f} |"
          " ValAcc {:.4f} | ETputs(KTEPS) {:.2f}".
          format(epoch, np.mean(dur), loss.item(), train_acc,
                 val_acc, n_edges / np.mean(dur) / 1000))

print()
if early_stop:
    model.load_state_dict(torch.load('es_checkpoint.pt'))
acc = evaluate(model, features, labels, test_mask)
print("Test Accuracy {:.4f}".format(acc))
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# ----Data statistics------'
#   #Edges 10556
#   #Classes 7
#   #Train samples 140
#   #Val samples 500
#   #Test samples 1000
# GAT(
#   (gat_layers): ModuleList(
#     (0): GATConv(
#       (fc): Linear(in_features=1433, out_features=128, bias=False)
#       (feat_drop): Dropout(p=0.06, inplace=False)
#       (attn_drop): Dropout(p=0.06, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GATConv(
#       (fc): Linear(in_features=128, out_features=64, bias=False)
#       (feat_drop): Dropout(p=0.06, inplace=False)
#       (attn_drop): Dropout(p=0.06, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (2): GATConv(
#       (fc): Linear(in_features=64, out_features=7, bias=False)
#       (feat_drop): Dropout(p=0.06, inplace=False)
#       (attn_drop): Dropout(p=0.06, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )
# Epoch 00000 | Time(s) nan | Loss 1.9393 | TrainAcc 0.2786 | ValAcc 0.5060 | ETputs(KTEPS) nan
# Epoch 00001 | Time(s) nan | Loss 1.8893 | TrainAcc 0.7143 | ValAcc 0.6160 | ETputs(KTEPS) nan
# Epoch 00002 | Time(s) nan | Loss 1.8338 | TrainAcc 0.7786 | ValAcc 0.6680 | ETputs(KTEPS) nan
# /home/ale/anaconda3/envs/wandb/lib/python3.8/site-packages/dgl/data/utils.py:288: UserWarning: Property dataset.num_labels will be deprecated, please use dataset.num_classes instead.
#   warnings.warn('Property {} will be deprecated, please use {} instead.'.format(old, new))
# /home/ale/anaconda3/envs/wandb/lib/python3.8/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# /home/ale/anaconda3/envs/wandb/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ale/anaconda3/envs/wandb/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00003 | Time(s) nan | Loss 1.7784 | TrainAcc 0.7857 | ValAcc 0.7360 | ETputs(KTEPS) nan
# Epoch 00004 | Time(s) nan | Loss 1.7137 | TrainAcc 0.8571 | ValAcc 0.7500 | ETputs(KTEPS) nan
# Epoch 00005 | Time(s) nan | Loss 1.6392 | TrainAcc 0.9286 | ValAcc 0.7240 | ETputs(KTEPS) nan
# Epoch 00006 | Time(s) nan | Loss 1.5577 | TrainAcc 0.9143 | ValAcc 0.7160 | ETputs(KTEPS) nan
# Epoch 00007 | Time(s) nan | Loss 1.4735 | TrainAcc 0.9000 | ValAcc 0.7720 | ETputs(KTEPS) nan
# Epoch 00008 | Time(s) nan | Loss 1.3840 | TrainAcc 0.9071 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00009 | Time(s) nan | Loss 1.2850 | TrainAcc 0.9214 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00010 | Time(s) nan | Loss 1.1955 | TrainAcc 0.9429 | ValAcc 0.7960 | ETputs(KTEPS) nan
# Epoch 00011 | Time(s) nan | Loss 1.0874 | TrainAcc 0.9357 | ValAcc 0.8100 | ETputs(KTEPS) nan
# Epoch 00012 | Time(s) nan | Loss 0.9604 | TrainAcc 0.9500 | ValAcc 0.8060 | ETputs(KTEPS) nan
# Epoch 00013 | Time(s) nan | Loss 0.8908 | TrainAcc 0.9571 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00014 | Time(s) nan | Loss 0.7761 | TrainAcc 0.9500 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00015 | Time(s) nan | Loss 0.6852 | TrainAcc 0.9500 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00016 | Time(s) nan | Loss 0.6042 | TrainAcc 0.9714 | ValAcc 0.8000 | ETputs(KTEPS) nan
# Epoch 00017 | Time(s) nan | Loss 0.5382 | TrainAcc 0.9786 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00018 | Time(s) nan | Loss 0.4674 | TrainAcc 0.9786 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00019 | Time(s) nan | Loss 0.4221 | TrainAcc 0.9786 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00020 | Time(s) nan | Loss 0.3769 | TrainAcc 0.9857 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00021 | Time(s) nan | Loss 0.3198 | TrainAcc 0.9929 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00022 | Time(s) nan | Loss 0.2776 | TrainAcc 0.9786 | ValAcc 0.8060 | ETputs(KTEPS) nan
# Epoch 00023 | Time(s) nan | Loss 0.2372 | TrainAcc 0.9857 | ValAcc 0.8060 | ETputs(KTEPS) nan
# Epoch 00024 | Time(s) nan | Loss 0.2069 | TrainAcc 0.9857 | ValAcc 0.8060 | ETputs(KTEPS) nan
# Epoch 00025 | Time(s) nan | Loss 0.1830 | TrainAcc 0.9786 | ValAcc 0.8040 | ETputs(KTEPS) nan
# Epoch 00026 | Time(s) nan | Loss 0.1657 | TrainAcc 0.9857 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00027 | Time(s) nan | Loss 0.1492 | TrainAcc 0.9857 | ValAcc 0.7960 | ETputs(KTEPS) nan
# Epoch 00028 | Time(s) nan | Loss 0.1510 | TrainAcc 0.9786 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00029 | Time(s) nan | Loss 0.1307 | TrainAcc 0.9786 | ValAcc 0.8040 | ETputs(KTEPS) nan
# Epoch 00030 | Time(s) nan | Loss 0.1105 | TrainAcc 0.9857 | ValAcc 0.8060 | ETputs(KTEPS) nan
# Epoch 00031 | Time(s) nan | Loss 0.0857 | TrainAcc 0.9929 | ValAcc 0.8020 | ETputs(KTEPS) nan
# Epoch 00032 | Time(s) nan | Loss 0.0908 | TrainAcc 0.9929 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00033 | Time(s) nan | Loss 0.0712 | TrainAcc 0.9929 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00034 | Time(s) nan | Loss 0.0837 | TrainAcc 0.9857 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00035 | Time(s) nan | Loss 0.0791 | TrainAcc 0.9857 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00036 | Time(s) nan | Loss 0.0740 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00037 | Time(s) nan | Loss 0.0667 | TrainAcc 0.9929 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00038 | Time(s) nan | Loss 0.0582 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00039 | Time(s) nan | Loss 0.0627 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00040 | Time(s) nan | Loss 0.0588 | TrainAcc 0.9929 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00041 | Time(s) nan | Loss 0.0571 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00042 | Time(s) nan | Loss 0.0476 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00043 | Time(s) nan | Loss 0.0439 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00044 | Time(s) nan | Loss 0.0677 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00045 | Time(s) nan | Loss 0.0550 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00046 | Time(s) nan | Loss 0.0534 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00047 | Time(s) nan | Loss 0.0524 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00048 | Time(s) nan | Loss 0.0471 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00049 | Time(s) nan | Loss 0.0571 | TrainAcc 1.0000 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00050 | Time(s) nan | Loss 0.0736 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00051 | Time(s) nan | Loss 0.0700 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00052 | Time(s) nan | Loss 0.0630 | TrainAcc 0.9929 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00053 | Time(s) nan | Loss 0.0484 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00054 | Time(s) nan | Loss 0.0442 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00055 | Time(s) nan | Loss 0.0515 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00056 | Time(s) nan | Loss 0.0648 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00057 | Time(s) nan | Loss 0.0542 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00058 | Time(s) nan | Loss 0.0827 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00059 | Time(s) nan | Loss 0.0685 | TrainAcc 0.9857 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00060 | Time(s) nan | Loss 0.0678 | TrainAcc 0.9929 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00061 | Time(s) nan | Loss 0.0481 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00062 | Time(s) nan | Loss 0.0550 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00063 | Time(s) nan | Loss 0.0463 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00064 | Time(s) nan | Loss 0.0642 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00065 | Time(s) nan | Loss 0.0547 | TrainAcc 1.0000 | ValAcc 0.7980 | ETputs(KTEPS) nan
# Epoch 00066 | Time(s) nan | Loss 0.0558 | TrainAcc 1.0000 | ValAcc 0.7960 | ETputs(KTEPS) nan
# Epoch 00067 | Time(s) nan | Loss 0.0889 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00068 | Time(s) nan | Loss 0.0743 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00069 | Time(s) nan | Loss 0.0541 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00070 | Time(s) nan | Loss 0.0531 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00071 | Time(s) nan | Loss 0.0635 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00072 | Time(s) nan | Loss 0.0649 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00073 | Time(s) nan | Loss 0.0397 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00074 | Time(s) nan | Loss 0.0634 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00075 | Time(s) nan | Loss 0.0584 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00076 | Time(s) nan | Loss 0.0439 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00077 | Time(s) nan | Loss 0.0636 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00078 | Time(s) nan | Loss 0.0554 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00079 | Time(s) nan | Loss 0.0490 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00080 | Time(s) nan | Loss 0.0486 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00081 | Time(s) nan | Loss 0.0518 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00082 | Time(s) nan | Loss 0.0428 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00083 | Time(s) nan | Loss 0.0530 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00084 | Time(s) nan | Loss 0.0407 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00085 | Time(s) nan | Loss 0.0581 | TrainAcc 0.9929 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00086 | Time(s) nan | Loss 0.0395 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00087 | Time(s) nan | Loss 0.0456 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00088 | Time(s) nan | Loss 0.0384 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00089 | Time(s) nan | Loss 0.0451 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00090 | Time(s) nan | Loss 0.0404 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00091 | Time(s) nan | Loss 0.0464 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00092 | Time(s) nan | Loss 0.0377 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00093 | Time(s) nan | Loss 0.0415 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00094 | Time(s) nan | Loss 0.0509 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00095 | Time(s) nan | Loss 0.0422 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00096 | Time(s) nan | Loss 0.0393 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00097 | Time(s) nan | Loss 0.0574 | TrainAcc 0.9929 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00098 | Time(s) nan | Loss 0.0472 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00099 | Time(s) nan | Loss 0.0409 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00100 | Time(s) nan | Loss 0.0430 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00101 | Time(s) nan | Loss 0.0443 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00102 | Time(s) nan | Loss 0.0457 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00103 | Time(s) nan | Loss 0.0489 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00104 | Time(s) nan | Loss 0.0283 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00105 | Time(s) nan | Loss 0.0344 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00106 | Time(s) nan | Loss 0.0433 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00107 | Time(s) nan | Loss 0.0631 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00108 | Time(s) nan | Loss 0.0338 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00109 | Time(s) nan | Loss 0.0537 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00110 | Time(s) nan | Loss 0.0344 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00111 | Time(s) nan | Loss 0.0447 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00112 | Time(s) nan | Loss 0.0450 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00113 | Time(s) nan | Loss 0.0531 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00114 | Time(s) nan | Loss 0.0463 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00115 | Time(s) nan | Loss 0.0464 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00116 | Time(s) nan | Loss 0.0464 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00117 | Time(s) nan | Loss 0.0369 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00118 | Time(s) nan | Loss 0.0440 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00119 | Time(s) nan | Loss 0.0609 | TrainAcc 0.9929 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00120 | Time(s) nan | Loss 0.0438 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00121 | Time(s) nan | Loss 0.0370 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00122 | Time(s) nan | Loss 0.0494 | TrainAcc 0.9929 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00123 | Time(s) nan | Loss 0.0346 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00124 | Time(s) nan | Loss 0.0554 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00125 | Time(s) nan | Loss 0.0503 | TrainAcc 0.9929 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00126 | Time(s) nan | Loss 0.0396 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00127 | Time(s) nan | Loss 0.0344 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00128 | Time(s) nan | Loss 0.0369 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00129 | Time(s) nan | Loss 0.0604 | TrainAcc 0.9929 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00130 | Time(s) nan | Loss 0.0476 | TrainAcc 0.9929 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00131 | Time(s) nan | Loss 0.0533 | TrainAcc 0.9929 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00132 | Time(s) nan | Loss 0.0467 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00133 | Time(s) nan | Loss 0.0307 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00134 | Time(s) nan | Loss 0.0442 | TrainAcc 0.9929 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00135 | Time(s) nan | Loss 0.0498 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00136 | Time(s) nan | Loss 0.0287 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00137 | Time(s) nan | Loss 0.0427 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00138 | Time(s) nan | Loss 0.0307 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00139 | Time(s) nan | Loss 0.0310 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00140 | Time(s) nan | Loss 0.0297 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00141 | Time(s) nan | Loss 0.0379 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00142 | Time(s) nan | Loss 0.0430 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00143 | Time(s) nan | Loss 0.0339 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00144 | Time(s) nan | Loss 0.0546 | TrainAcc 0.9929 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00145 | Time(s) nan | Loss 0.0369 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00146 | Time(s) nan | Loss 0.0498 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00147 | Time(s) nan | Loss 0.0434 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00148 | Time(s) nan | Loss 0.0402 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00149 | Time(s) nan | Loss 0.0523 | TrainAcc 0.9929 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00150 | Time(s) nan | Loss 0.0314 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00151 | Time(s) nan | Loss 0.0626 | TrainAcc 0.9929 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00152 | Time(s) nan | Loss 0.0306 | TrainAcc 1.0000 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00153 | Time(s) nan | Loss 0.0365 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00154 | Time(s) nan | Loss 0.0259 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00155 | Time(s) nan | Loss 0.0376 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00156 | Time(s) nan | Loss 0.0309 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00157 | Time(s) nan | Loss 0.0359 | TrainAcc 0.9929 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00158 | Time(s) nan | Loss 0.0325 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00159 | Time(s) nan | Loss 0.0401 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00160 | Time(s) nan | Loss 0.0498 | TrainAcc 0.9929 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00161 | Time(s) nan | Loss 0.0490 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00162 | Time(s) nan | Loss 0.0276 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00163 | Time(s) nan | Loss 0.0592 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00164 | Time(s) nan | Loss 0.0358 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00165 | Time(s) nan | Loss 0.0298 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00166 | Time(s) nan | Loss 0.0480 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00167 | Time(s) nan | Loss 0.0412 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00168 | Time(s) nan | Loss 0.0246 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00169 | Time(s) nan | Loss 0.0393 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00170 | Time(s) nan | Loss 0.0576 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00171 | Time(s) nan | Loss 0.0287 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00172 | Time(s) nan | Loss 0.0297 | TrainAcc 1.0000 | ValAcc 0.7740 | ETputs(KTEPS) nan
# Epoch 00173 | Time(s) nan | Loss 0.0329 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00174 | Time(s) nan | Loss 0.0522 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00175 | Time(s) nan | Loss 0.0445 | TrainAcc 0.9929 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00176 | Time(s) nan | Loss 0.0412 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00177 | Time(s) nan | Loss 0.0414 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00178 | Time(s) nan | Loss 0.0346 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00179 | Time(s) nan | Loss 0.0458 | TrainAcc 0.9929 | ValAcc 0.7780 | ETputs(KTEPS) nan
# Epoch 00180 | Time(s) nan | Loss 0.0384 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
# Epoch 00181 | Time(s) nan | Loss 0.0336 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00182 | Time(s) nan | Loss 0.0323 | TrainAcc 1.0000 | ValAcc 0.7800 | ETputs(KTEPS) nan
# Epoch 00183 | Time(s) nan | Loss 0.0353 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00184 | Time(s) nan | Loss 0.0504 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00185 | Time(s) nan | Loss 0.0305 | TrainAcc 1.0000 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00186 | Time(s) nan | Loss 0.0315 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00187 | Time(s) nan | Loss 0.0301 | TrainAcc 1.0000 | ValAcc 0.7920 | ETputs(KTEPS) nan
# Epoch 00188 | Time(s) nan | Loss 0.0438 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00189 | Time(s) nan | Loss 0.0333 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00190 | Time(s) nan | Loss 0.0376 | TrainAcc 1.0000 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00191 | Time(s) nan | Loss 0.0310 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00192 | Time(s) nan | Loss 0.0335 | TrainAcc 1.0000 | ValAcc 0.7820 | ETputs(KTEPS) nan
# Epoch 00193 | Time(s) nan | Loss 0.0420 | TrainAcc 0.9929 | ValAcc 0.7840 | ETputs(KTEPS) nan
# Epoch 00194 | Time(s) nan | Loss 0.0375 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00195 | Time(s) nan | Loss 0.0246 | TrainAcc 1.0000 | ValAcc 0.7940 | ETputs(KTEPS) nan
# Epoch 00196 | Time(s) nan | Loss 0.0458 | TrainAcc 0.9929 | ValAcc 0.7900 | ETputs(KTEPS) nan
# Epoch 00197 | Time(s) nan | Loss 0.0292 | TrainAcc 1.0000 | ValAcc 0.7880 | ETputs(KTEPS) nan
# Epoch 00198 | Time(s) nan | Loss 0.0301 | TrainAcc 1.0000 | ValAcc 0.7860 | ETputs(KTEPS) nan
# Epoch 00199 | Time(s) nan | Loss 0.0368 | TrainAcc 1.0000 | ValAcc 0.7760 | ETputs(KTEPS) nan
#
# Test Accuracy 0.7980
